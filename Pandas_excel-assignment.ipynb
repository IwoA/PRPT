# %% [markdown]
# # 99 Bikers Customer Demographic Analysis

# %%
import pandas as pd

# %% [markdown]
# What sheets do we have?

# %%
xl = pd.ExcelFile()
print("Sheet names:", xl.sheet_names)
# Out:
# Sheet names: ['Transactions', 'NewCustomerList', 'CustomerDemographic', 'CustomerAddress']

# %% [markdown]
# Load fourth sheet.

# %%
CustomerAddress = pd.read_excel()

# %% [markdown]
# Show first few rows.

# %%
CustomerAddress.
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %% [markdown]
# In what states clients live? How many states are in our dataset?

# %%
.unique()
# Out:
# array(['New South Wales', 'QLD', 'VIC', 'NSW', 'Victoria'], dtype=object)

# %% [markdown]
# How many clients live in each state?

# %%
groupby().count().sort_values(, ascending=False)
# Out:
#                  customer_id  address  postcode  country  property_valuation
# state
# NSW                     2054     2054      2054     2054                2054
# VIC                      939      939       939      939                 939
# QLD                      838      838       838      838                 838
# New South Wales           86       86        86       86                  86
# Victoria                  82       82        82       82                  82

# %% [markdown]
# Half of them live in NSW.

# %% [markdown]
# Apparently NSW = New South Wales and VIC = Victoria. You have to change these values.

# %%
CustomerAddress[] = CustomerAddress[].replace({

})

# %% [markdown]
# Let's repeat previous step to verify how many states do we really have.

# %%
.groupby().count().sort_values(, ascending=False)
# Out:
#        customer_id  address  postcode  country  property_valuation
# state
# NSW           2140     2140      2140     2140                2140
# VIC           1021     1021      1021     1021                1021
# QLD            838      838       838      838                 838

# %% [markdown]
# What is a mean property valuation per state?

# %%
# Write your code here
# Out:
#        customer_id  postcode  property_valuation
# state
# NSW         1975.0    2315.0                 8.0
# QLD         2000.0    4331.0                 6.0
# VIC         2068.0    3288.0                 7.0

# %% [markdown]
# Show mean and median in one table.

# %%
# Write your code here
# Out:
#       property_valuation
#                     mean median
# state
# NSW             8.391589    9.0
# QLD             5.569212    6.0
# VIC             7.272282    8.0

# %% [markdown]
# How many customers are in each property class in each state? Which property valuation is most common in each state? Are there any differences?

# %%
# Write your code here
# Out:
#                           customer_id  address  postcode  country
# state property_valuation
# NSW   1                            64       64        64       64
#       2                            38       38        38       38
#       3                            48       48        48       48
#       4                            67       67        67       67
#       5                            71       71        71       71
#       6                            75       75        75       75
#       7                           190      190       190      190
#       8                           357      357       357      357
#       9                           432      432       432      432
#       10                          411      411       411      411
#       11                          227      227       227      227
#       12                          160      160       160      160
# QLD   1                            48       48        48       48
# ...

# %% [markdown]
# Let's check if there are customers living on the same street. `str.replace` function can be useful here.

# %%
CustomerAddress['street'] = .str.replace(, "", regex = True)

# %%
CustomerAddress.head()
# Out:
#    customer_id              address  postcode state    country  \
# 0            1   060 Morning Avenue      2016   NSW  Australia
# 1            2  6 Meadow Vale Court      2153   NSW  Australia
# 2            4   0 Holy Cross Court      4211   QLD  Australia
# 3            5  17979 Del Mar Point      2448   NSW  Australia
# 4            6     9 Oakridge Court      3216   VIC  Australia
#
#    property_valuation             street
# 0                  10     Morning Avenue
# 1                  10  Meadow Vale Court
# 2                   9   Holy Cross Court
# 3                   4      Del Mar Point
# 4                   9     Oakridge Court

# %% [markdown]
# Is it possible that the same street names are in different states?

# %%
.filter(lambda x: len(x) > 1).sort_values('street')
# Out:
#       customer_id                 address  postcode state    country  \
# 15             18           092 2nd Alley      2135   NSW  Australia
# 531           536         64700 2nd Alley      2145   NSW  Australia
# 1688         1693          419 2nd Center      4220   QLD  Australia
# 912           917           50 2nd Center      3188   VIC  Australia
# 3038         3043            05 2nd Point      2217   NSW  Australia
# ...           ...                     ...       ...   ...        ...
# 2696         2701      41 Westport Center      3280   VIC  Australia
# 3057         3062         6 Westport Road      4350   QLD  Australia
# 815           820     58047 Westport Road      2040   NSW  Australia
# 2387         2392  69810 Westridge Avenue      2573   NSW  Australia
# 3624         3629      3 Westridge Avenue      2810   NSW  Australia
#
#       property_valuation            street
# 15                    12         2nd Alley
# 531                    7         2nd Alley
# ...

# %% [markdown]
# What is a number of customers living at the same street?

# %%
counted = .count()
counted
# Out:
#                          customer_id  address  postcode  country  \
# state street
# NSW   1st Park                     1        1         1        1
#       2nd Alley                    2        2         2        2
#       2nd Lane                     1        1         1        1
#       2nd Pass                     1        1         1        1
#       2nd Plaza                    1        1         1        1
# ...                              ...      ...       ...      ...
# VIC   Westend Hill                 1        1         1        1
#       Westerfield Trail            1        1         1        1
#       Westport Center              1        1         1        1
#       Westport Pass                1        1         1        1
#       Westridge Road               1        1         1        1
#
#                          property_valuation
# state street
# NSW   1st Park                            1
#       2nd Alley                           2
# ...

# %% [markdown]
# How many streets have a customer count greater than one? Sort streets in descending orderof counts. What is max customer count?

# %%
counted1 = counted[]
counted1
# Out:
#                         customer_id  address  postcode  country  \
# state street
# NSW   Monterey Terrace            3        3         3        3
#       Donald Crossing             3        3         3        3
#       Sundown Trail               3        3         3        3
#       Dayton Park                 3        3         3        3
# VIC   Moland Street               3        3         3        3
# ...                             ...      ...       ...      ...
# NSW   Knutson Crossing            2        2         2        2
#       Lakewood Street             2        2         2        2
#       Lindbergh Drive             2        2         2        2
#       Londonderry Park            2        2         2        2
# VIC   Vidon Way                   2        2         2        2
#
#                         property_valuation
# state street
# NSW   Monterey Terrace                   3
#       Donald Crossing                    3
# ...

# %% [markdown]
# In which states are these streets located?

# %%
counted1.index.get_level_values().
# Out:
# Index(['NSW', 'VIC', 'QLD'], dtype='object', name='state')

# %% [markdown]
# From the dataset filter only streets where customer count is higher than 1 and save it as a new Excel file.

# %%
streets = 
filtered = CustomerAddress[.isin]
filtered.to_excel()
